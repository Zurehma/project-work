# %%
from Problem import Problem
from s323502 import solution

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 1===")
case=Problem(100, density=0.2, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 31249.2204
# Gen 100: Best Cost = 25283.4800
# Gen 200: Best Cost = 25253.1917
# Gen 300: Best Cost = 25249.4669
# Gen 400: Best Cost = 25247.1934
# Gen 500: Best Cost = 25246.1536
# Gen 600: Best Cost = 25244.0279
# Gen 700: Best Cost = 25241.8113
# Gen 800: Best Cost = 25241.8113
# Gen 900: Best Cost = 25241.8113
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  25266.40561851071
# GA Solution:    25241.811288168163
# IMPROVEMENT:    24.594330342548346 (0.10%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 0.5===")
case=Problem(100, density=0.2, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2302.6361
# Gen 100: Best Cost = 1833.6140
# Gen 200: Best Cost = 1739.8224
# Gen 300: Best Cost = 1687.1302
# Gen 400: Best Cost = 1658.6973
# Gen 500: Best Cost = 1650.6925
# Gen 600: Best Cost = 1619.6581
# Gen 700: Best Cost = 1618.6853
# Gen 800: Best Cost = 1618.6853
# Gen 900: Best Cost = 1614.7369
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  2231.047939971318
# GA Solution:    1614.736927081034
# IMPROVEMENT:    616.311012890284 (27.62%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 2===")
case=Problem(100, density=0.2, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 8050845.8792
# Gen 100: Best Cost = 5088590.0883
# Gen 200: Best Cost = 4959983.2092
# Gen 300: Best Cost = 4926539.2342
# Gen 400: Best Cost = 4926539.2342
# Gen 500: Best Cost = 4926539.2342
# Gen 600: Best Cost = 4926179.5877
# Gen 700: Best Cost = 4926179.5877
# Gen 800: Best Cost = 4926179.5877
# Gen 900: Best Cost = 4926179.5877
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  5334401.927002504
# GA Solution:    4926179.587661133
# IMPROVEMENT:    408222.3393413704 (7.65%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 3===")
case=Problem(100, density=0.2, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2521089717.6704
# Gen 100: Best Cost = 1143172591.0670
# Gen 200: Best Cost = 1102078376.8935
# Gen 300: Best Cost = 1067508299.8997
# Gen 400: Best Cost = 1058079322.5812
# Gen 500: Best Cost = 1056061204.9779
# Gen 600: Best Cost = 1054474419.5513
# Gen 700: Best Cost = 1046395851.4765
# Gen 800: Best Cost = 1046395851.4765
# Gen 900: Best Cost = 1046395851.4765
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1504133861.145873
# GA Solution:    1046395851.4764576
# IMPROVEMENT:    457738009.6694155 (30.43%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 5===")
case=Problem(100, density=0.2, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 719480332501488.2500
# Gen 100: Best Cost = 72497998151609.2344
# Gen 200: Best Cost = 60588140153541.0312
# Gen 300: Best Cost = 56597955766587.8438
# Gen 400: Best Cost = 56537963954561.1562
# Gen 500: Best Cost = 56537963954561.1562
# Gen 600: Best Cost = 54468837773057.1719
# Gen 700: Best Cost = 52271150296579.0859
# Gen 800: Best Cost = 51979452045712.1172
# Gen 900: Best Cost = 51979452045712.1016
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  187088165532885.75
# GA Solution:    51979452045712.1
# IMPROVEMENT:    135108713487173.66 (72.22%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 0.2, alpha 2, beta 1===")
case=Problem(100, density=0.2, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 60485.9336
# Gen 100: Best Cost = 50427.5133
# Gen 200: Best Cost = 50418.8378
# Gen 300: Best Cost = 50415.3089
# Gen 400: Best Cost = 50409.4572
# Gen 500: Best Cost = 50407.6159
# Gen 600: Best Cost = 50406.0898
# Gen 700: Best Cost = 50402.6590
# Gen 800: Best Cost = 50402.6590
# Gen 900: Best Cost = 50401.4851
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  50425.309618179184
# GA Solution:    50401.13398541341
# IMPROVEMENT:    24.175632765771297 (0.05%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 1===")
case=Problem(100, density=1, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 19167.3396
# Gen 100: Best Cost = 18264.7308
# Gen 200: Best Cost = 18260.5930
# Gen 300: Best Cost = 18257.0251
# Gen 400: Best Cost = 18255.2241
# Gen 500: Best Cost = 18254.4045
# Gen 600: Best Cost = 18253.9802
# Gen 700: Best Cost = 18253.9540
# Gen 800: Best Cost = 18253.9540
# Gen 900: Best Cost = 18253.9540
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  18266.185795826725
# GA Solution:    18253.953957344347
# IMPROVEMENT:    12.231838482377498 (0.07%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 0.5===")
case=Problem(100, density=1, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 1307.5762
# Gen 100: Best Cost = 1148.1406
# Gen 200: Best Cost = 1116.0472
# Gen 300: Best Cost = 1104.7654
# Gen 400: Best Cost = 1092.4543
# Gen 500: Best Cost = 1088.7320
# Gen 600: Best Cost = 1083.8891
# Gen 700: Best Cost = 1079.7941
# Gen 800: Best Cost = 1077.6823
# Gen 900: Best Cost = 1077.6823
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1292.6308177628093
# GA Solution:    1077.6822938767798
# IMPROVEMENT:    214.94852388602953 (16.63%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 2===")
case=Problem(100, density=1, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 6340829.3425
# Gen 100: Best Cost = 4569267.5188
# Gen 200: Best Cost = 4319000.2935
# Gen 300: Best Cost = 4305449.3661
# Gen 400: Best Cost = 4281468.0507
# Gen 500: Best Cost = 4252365.1890
# Gen 600: Best Cost = 4252086.3312
# Gen 700: Best Cost = 4242080.0359
# Gen 800: Best Cost = 4242080.0359
# Gen 900: Best Cost = 4231719.5062
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  5404978.08899582
# GA Solution:    4231719.506200435
# IMPROVEMENT:    1173258.5827953853 (21.71%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 3===")
case=Problem(100, density=1, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2472255560.5251
# Gen 100: Best Cost = 1254574620.6970
# Gen 200: Best Cost = 1122722081.5998
# Gen 300: Best Cost = 1091610642.2425
# Gen 400: Best Cost = 1074843103.2974
# Gen 500: Best Cost = 1060143235.1538
# Gen 600: Best Cost = 1047903665.6092
# Gen 700: Best Cost = 1044194266.7256
# Gen 800: Best Cost = 1043361906.1202
# Gen 900: Best Cost = 1042935504.0011
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1957078935.0665622
# GA Solution:    1041365721.3525174
# IMPROVEMENT:    915713213.7140448 (46.79%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 5===")
case=Problem(100, density=1, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 344103067608374.3125
# Gen 100: Best Cost = 106053375916464.4688
# Gen 200: Best Cost = 86620390977302.2656
# Gen 300: Best Cost = 83117394788692.1562
# Gen 400: Best Cost = 79669906627103.2344
# Gen 500: Best Cost = 75083070420520.1719
# Gen 600: Best Cost = 72832145067677.6719
# Gen 700: Best Cost = 72266969776800.8125
# Gen 800: Best Cost = 72166755952879.7656
# Gen 900: Best Cost = 71504319905349.8281
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  347651302495115.3
# GA Solution:    69767469033008.7
# IMPROVEMENT:    277883833462106.62 (79.93%)
# ----------------------------------------

# %%
print("===Test Case: 100 cities, density 1, alpha 2, beta 1===")
case=Problem(100, density=1, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 38924.6373
# Gen 100: Best Cost = 36455.8278
# Gen 200: Best Cost = 36453.7041
# Gen 300: Best Cost = 36452.3784
# Gen 400: Best Cost = 36452.2357
# Gen 500: Best Cost = 36451.2395
# Gen 600: Best Cost = 36450.8258
# Gen 700: Best Cost = 36450.3169
# Gen 800: Best Cost = 36450.2701
# Gen 900: Best Cost = 36450.2701
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  36457.91846237206
# GA Solution:    36450.2700548645
# IMPROVEMENT:    7.64840750755684 (0.02%)
# ----------------------------------------
