# %%
from Problem import Problem
from s323502 import solution

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 1===")
case=Problem(100, density=0.2, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 29827.2022
# Gen 100: Best Cost = 25273.6872
# Gen 200: Best Cost = 25255.8113
# Gen 300: Best Cost = 25252.1426
# Gen 400: Best Cost = 25248.9331
# Gen 500: Best Cost = 25245.7796
# Gen 600: Best Cost = 25245.7796
# Gen 700: Best Cost = 25244.0193
# Gen 800: Best Cost = 25242.9731
# Gen 900: Best Cost = 25242.3230
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  25266.40561851071
# GA Solution:    25242.29782245495
# IMPROVEMENT:    24.107796055759536 (0.10%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 0.5===")
case=Problem(100, density=0.2, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2350.3404
# Gen 100: Best Cost = 1838.3070
# Gen 200: Best Cost = 1745.5530
# Gen 300: Best Cost = 1724.7636
# Gen 400: Best Cost = 1713.4453
# Gen 500: Best Cost = 1699.4665
# Gen 600: Best Cost = 1691.8462
# Gen 700: Best Cost = 1672.9892
# Gen 800: Best Cost = 1672.5995
# Gen 900: Best Cost = 1669.2488
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  2231.047939971318
# GA Solution:    1665.2985864415373
# IMPROVEMENT:    565.7493535297808 (25.36%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 2===")
case=Problem(100, density=0.2, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 7629176.9686
# Gen 100: Best Cost = 5123446.6299
# Gen 200: Best Cost = 5008016.3085
# Gen 300: Best Cost = 4972052.9245
# Gen 400: Best Cost = 4972052.9245
# Gen 500: Best Cost = 4972052.9245
# Gen 600: Best Cost = 4956269.0197
# Gen 700: Best Cost = 4951583.8895
# Gen 800: Best Cost = 4944104.6436
# Gen 900: Best Cost = 4944104.6436
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  5334401.927002504
# GA Solution:    4944104.643559127
# IMPROVEMENT:    390297.2834433764 (7.32%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 3===")
case=Problem(100, density=0.2, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2384938636.1763
# Gen 100: Best Cost = 1104511458.4519
# Gen 200: Best Cost = 1092826701.5083
# Gen 300: Best Cost = 1080890276.0941
# Gen 400: Best Cost = 1074060882.9413
# Gen 500: Best Cost = 1070642385.8582
# Gen 600: Best Cost = 1070642385.8582
# Gen 700: Best Cost = 1070642385.8582
# Gen 800: Best Cost = 1070642385.8582
# Gen 900: Best Cost = 1057191771.7631
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1504133861.145873
# GA Solution:    1056036949.8762105
# IMPROVEMENT:    448096911.2696626 (29.79%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 0.2, alpha 1, beta 5===")
case=Problem(100, density=0.2, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 501631019019713.4375
# Gen 100: Best Cost = 72544738148459.1562
# Gen 200: Best Cost = 59093668329783.5859
# Gen 300: Best Cost = 56269611636321.0547
# Gen 400: Best Cost = 54434635946888.7969
# Gen 500: Best Cost = 53544010676115.8594
# Gen 600: Best Cost = 53544010676115.8516
# Gen 700: Best Cost = 52951256520789.0547
# Gen 800: Best Cost = 52951256520789.0469
# Gen 900: Best Cost = 52951256520789.0469
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  187088165532885.75
# GA Solution:    52951256520789.05
# IMPROVEMENT:    134136909012096.7 (71.70%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 0.2, alpha 2, beta 1===")
case=Problem(100, density=0.2, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 0.2, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 61187.7824
# Gen 100: Best Cost = 50416.4408
# Gen 200: Best Cost = 50410.4893
# Gen 300: Best Cost = 50408.3743
# Gen 400: Best Cost = 50405.3102
# Gen 500: Best Cost = 50403.3361
# Gen 600: Best Cost = 50402.1152
# Gen 700: Best Cost = 50398.6031
# Gen 800: Best Cost = 50397.7877
# Gen 900: Best Cost = 50397.7877
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  50425.309618179184
# GA Solution:    50397.78770139967
# IMPROVEMENT:    27.521916779514868 (0.05%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 1===")
case=Problem(100, density=1, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 19654.4731
# Gen 100: Best Cost = 18262.9843
# Gen 200: Best Cost = 18258.2161
# Gen 300: Best Cost = 18257.1596
# Gen 400: Best Cost = 18255.6184
# Gen 500: Best Cost = 18254.9479
# Gen 600: Best Cost = 18254.9479
# Gen 700: Best Cost = 18254.5877
# Gen 800: Best Cost = 18254.5309
# Gen 900: Best Cost = 18254.5309
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  18266.185795826725
# GA Solution:    18254.5309095713
# IMPROVEMENT:    11.65488625542639 (0.06%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 0.5===")
case=Problem(100, density=1, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 1323.3310
# Gen 100: Best Cost = 1157.7462
# Gen 200: Best Cost = 1122.4468
# Gen 300: Best Cost = 1106.7856
# Gen 400: Best Cost = 1096.4285
# Gen 500: Best Cost = 1088.1990
# Gen 600: Best Cost = 1081.4370
# Gen 700: Best Cost = 1078.7482
# Gen 800: Best Cost = 1077.8726
# Gen 900: Best Cost = 1077.8726
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1292.6308177628093
# GA Solution:    1077.872627659584
# IMPROVEMENT:    214.7581901032254 (16.61%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 2===")
case=Problem(100, density=1, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 6233685.3111
# Gen 100: Best Cost = 4467719.7417
# Gen 200: Best Cost = 4344644.4104
# Gen 300: Best Cost = 4333681.7182
# Gen 400: Best Cost = 4303813.1914
# Gen 500: Best Cost = 4303813.1914
# Gen 600: Best Cost = 4294865.0880
# Gen 700: Best Cost = 4289077.1844
# Gen 800: Best Cost = 4289077.1844
# Gen 900: Best Cost = 4274828.2155
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  5404978.08899582
# GA Solution:    4274828.215465008
# IMPROVEMENT:    1130149.8735308116 (20.91%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 3===")
case=Problem(100, density=1, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 2387123910.9791
# Gen 100: Best Cost = 1215166571.2377
# Gen 200: Best Cost = 1095724390.6467
# Gen 300: Best Cost = 1081015656.6448
# Gen 400: Best Cost = 1051818724.3812
# Gen 500: Best Cost = 1049210155.4829
# Gen 600: Best Cost = 1044516937.5097
# Gen 700: Best Cost = 1042119592.6690
# Gen 800: Best Cost = 1028524676.5435
# Gen 900: Best Cost = 1026048561.9161
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1957078935.0665622
# GA Solution:    1026048561.9161129
# IMPROVEMENT:    931030373.1504493 (47.57%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 1, beta 5===")
case=Problem(100, density=1, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 478292063922489.7500
# Gen 100: Best Cost = 104151577250441.1406
# Gen 200: Best Cost = 97645070703820.8594
# Gen 300: Best Cost = 86979149762344.5625
# Gen 400: Best Cost = 84952394947735.3438
# Gen 500: Best Cost = 84340409097064.5625
# Gen 600: Best Cost = 82000467637411.7031
# Gen 700: Best Cost = 81750544996651.0000
# Gen 800: Best Cost = 80163635387938.4844
# Gen 900: Best Cost = 80163635387938.4844
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  347651302495115.3
# GA Solution:    79295038665085.72
# IMPROVEMENT:    268356263830029.6 (77.19%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 100 cities, density 1, alpha 2, beta 1===")
case=Problem(100, density=1, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 100 cities, density 1, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 38712.7407
# Gen 100: Best Cost = 36455.2047
# Gen 200: Best Cost = 36453.5855
# Gen 300: Best Cost = 36450.9630
# Gen 400: Best Cost = 36450.9478
# Gen 500: Best Cost = 36450.6546
# Gen 600: Best Cost = 36450.6546
# Gen 700: Best Cost = 36450.6546
# Gen 800: Best Cost = 36450.1308
# Gen 900: Best Cost = 36450.1308
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  36457.91846237206
# GA Solution:    36449.88271571979
# IMPROVEMENT:    8.035746652269154 (0.02%)
# ----------------------------------------
# Validating path...
# Path is valid
