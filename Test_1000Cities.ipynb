# %%
from Problem import Problem
from s323502 import solution

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 1===")
case=Problem(1000, density=0.2, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 223529.0523
# Gen 100: Best Cost = 201319.5579
# Gen 200: Best Cost = 196712.6602
# Gen 300: Best Cost = 195754.5219
# Gen 400: Best Cost = 195490.6366
# Gen 500: Best Cost = 195418.7227
# Gen 600: Best Cost = 195397.9620
# Gen 700: Best Cost = 195392.9759
# Gen 800: Best Cost = 195388.7008
# Gen 900: Best Cost = 195384.9393
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  195402.95810394033
# GA Solution:    195382.05750408617
# IMPROVEMENT:    20.90059985415428 (0.01%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 0.5===")
case=Problem(1000, density=0.2, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 19861.9670
# Gen 100: Best Cost = 18153.2906
# Gen 200: Best Cost = 17621.1411
# Gen 300: Best Cost = 17250.9479
# Gen 400: Best Cost = 16974.0142
# Gen 500: Best Cost = 16772.3733
# Gen 600: Best Cost = 16536.6154
# Gen 700: Best Cost = 16351.1646
# Gen 800: Best Cost = 16223.5943
# Gen 900: Best Cost = 16080.7640
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  18717.20987451334
# GA Solution:    15923.314081045115
# IMPROVEMENT:    2793.8957934682257 (14.93%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 2===")
case=Problem(1000, density=0.2, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 54161349.8877
# Gen 100: Best Cost = 35458751.3915
# Gen 200: Best Cost = 32304427.7464
# Gen 300: Best Cost = 30648473.5821
# Gen 400: Best Cost = 29570561.3065
# Gen 500: Best Cost = 29014383.0214
# Gen 600: Best Cost = 28323210.0723
# Gen 700: Best Cost = 27716350.9831
# Gen 800: Best Cost = 27297467.6835
# Gen 900: Best Cost = 26950354.9750
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  37545927.702134684
# GA Solution:    26618993.03641113
# IMPROVEMENT:    10926934.665723555 (29.10%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 3===")
case=Problem(1000, density=0.2, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 22111968699.6693
# Gen 100: Best Cost = 8592783783.3694
# Gen 200: Best Cost = 7144064939.7646
# Gen 300: Best Cost = 6229290897.0717
# Gen 400: Best Cost = 5683150738.4004
# Gen 500: Best Cost = 5296444462.6065
# Gen 600: Best Cost = 5039701671.4647
# Gen 700: Best Cost = 4856518196.7414
# Gen 800: Best Cost = 4676769576.4050
# Gen 900: Best Cost = 4511435983.5745
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  10600895130.62203
# GA Solution:    4406402569.0227375
# IMPROVEMENT:    6194492561.599293 (58.43%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 5===")
case=Problem(1000, density=0.2, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 5228272354828605.0000
# Gen 100: Best Cost = 729303791960457.1250
# Gen 200: Best Cost = 444554357032548.6250
# Gen 300: Best Cost = 348768220273096.0000
# Gen 400: Best Cost = 288897181816681.6250
# Gen 500: Best Cost = 246512720427140.8750
# Gen 600: Best Cost = 212430302441940.6562
# Gen 700: Best Cost = 188978151692556.8125
# Gen 800: Best Cost = 172238291796412.9062
# Gen 900: Best Cost = 161011432785177.1250
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1575163721306340.5
# GA Solution:    147669971370394.56
# IMPROVEMENT:    1427493749935946.0 (90.63%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 2, beta 1===")
case=Problem(1000, density=0.2, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 449429.3519
# Gen 100: Best Cost = 400543.8732
# Gen 200: Best Cost = 392186.1458
# Gen 300: Best Cost = 390409.4235
# Gen 400: Best Cost = 390109.4878
# Gen 500: Best Cost = 390041.4178
# Gen 600: Best Cost = 390023.0710
# Gen 700: Best Cost = 390020.3910
# Gen 800: Best Cost = 390018.6917
# Gen 900: Best Cost = 390017.3788
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  390028.7212628889
# GA Solution:    390014.01515848545
# IMPROVEMENT:    14.706104403478093 (0.00%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 1===")
case=Problem(1000, density=1, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 219922.1848
# Gen 100: Best Cost = 195748.2979
# Gen 200: Best Cost = 193385.9864
# Gen 300: Best Cost = 192993.4072
# Gen 400: Best Cost = 192936.3754
# Gen 500: Best Cost = 192923.3129
# Gen 600: Best Cost = 192910.1173
# Gen 700: Best Cost = 192899.8001
# Gen 800: Best Cost = 192893.7273
# Gen 900: Best Cost = 192885.9570
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  192936.23377726728
# GA Solution:    192876.37642967404
# IMPROVEMENT:    59.85734759323532 (0.03%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 0.5===")
case=Problem(1000, density=1, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 14192.2104
# Gen 100: Best Cost = 13235.0591
# Gen 200: Best Cost = 12984.3604
# Gen 300: Best Cost = 12744.3910
# Gen 400: Best Cost = 12567.2608
# Gen 500: Best Cost = 12424.0640
# Gen 600: Best Cost = 12301.0192
# Gen 700: Best Cost = 12186.7775
# Gen 800: Best Cost = 12101.3426
# Gen 900: Best Cost = 12010.9485
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  13456.958529427162
# GA Solution:    11949.103894178003
# IMPROVEMENT:    1507.8546352491594 (11.21%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 2===")
case=Problem(1000, density=1, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 81460033.3514
# Gen 100: Best Cost = 57062231.1404
# Gen 200: Best Cost = 54113739.0232
# Gen 300: Best Cost = 52211777.1960
# Gen 400: Best Cost = 50883250.5312
# Gen 500: Best Cost = 49982377.8774
# Gen 600: Best Cost = 49231211.3959
# Gen 700: Best Cost = 48572265.5091
# Gen 800: Best Cost = 48107839.1155
# Gen 900: Best Cost = 47608432.7128
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  57580018.86872494
# GA Solution:    47317292.83506815
# IMPROVEMENT:    10262726.03365679 (17.82%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 3===")
case=Problem(1000, density=1, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 39868279859.0319
# Gen 100: Best Cost = 19881082033.0356
# Gen 200: Best Cost = 17341921318.2852
# Gen 300: Best Cost = 16222087415.9829
# Gen 400: Best Cost = 15349848863.0544
# Gen 500: Best Cost = 14726739259.4024
# Gen 600: Best Cost = 14185175235.7338
# Gen 700: Best Cost = 13793632196.4216
# Gen 800: Best Cost = 13431506701.9761
# Gen 900: Best Cost = 13132774177.1517
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  20943050223.626434
# GA Solution:    12865087264.811377
# IMPROVEMENT:    8077962958.815058 (38.57%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 5===")
case=Problem(1000, density=1, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 16388424279684342.0000
# Gen 100: Best Cost = 3610535144474020.5000
# Gen 200: Best Cost = 2548624395297578.0000
# Gen 300: Best Cost = 2094658558364236.2500
# Gen 400: Best Cost = 1743424706408875.5000
# Gen 500: Best Cost = 1570752200385872.5000
# Gen 600: Best Cost = 1434411462305150.5000
# Gen 700: Best Cost = 1294205584124792.2500
# Gen 800: Best Cost = 1206589457100284.7500
# Gen 900: Best Cost = 1130809452795141.0000
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  3798422113393744.0
# GA Solution:    1100156189639249.0
# IMPROVEMENT:    2698265923754495.0 (71.04%)
# ----------------------------------------
# Validating path...
# Path is valid

# %%
print("===Test Case: 1000 cities, density 1, alpha 2, beta 1===")
case=Problem(1000, density=1, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 435695.3921
# Gen 100: Best Cost = 391434.8066
# Gen 200: Best Cost = 386433.5235
# Gen 300: Best Cost = 385377.9639
# Gen 400: Best Cost = 385148.4974
# Gen 500: Best Cost = 385098.8441
# Gen 600: Best Cost = 385092.3022
# Gen 700: Best Cost = 385085.1387
# Gen 800: Best Cost = 385078.3511
# Gen 900: Best Cost = 385071.2578
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  385105.6414957661
# GA Solution:    385064.0647266584
# IMPROVEMENT:    41.57676910771988 (0.01%)
# ----------------------------------------
# Validating path...
# Path is valid
