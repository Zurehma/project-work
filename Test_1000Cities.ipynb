# %%
from Problem import Problem
from s323502 import solution

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 1===")
case=Problem(1000, density=0.2, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 225458.5784
# Gen 100: Best Cost = 198932.4204
# Gen 200: Best Cost = 196152.8467
# Gen 300: Best Cost = 195549.4360
# Gen 400: Best Cost = 195409.9137
# Gen 500: Best Cost = 195394.5007
# Gen 600: Best Cost = 195389.6828
# Gen 700: Best Cost = 195386.8020
# Gen 800: Best Cost = 195383.9121
# Gen 900: Best Cost = 195381.1901
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  195402.95810394033
# GA Solution:    195378.79498205835
# IMPROVEMENT:    24.16312188198208 (0.01%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 0.5===")
case=Problem(1000, density=0.2, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 19696.7165
# Gen 100: Best Cost = 18094.4533
# Gen 200: Best Cost = 17568.3931
# Gen 300: Best Cost = 17176.6407
# Gen 400: Best Cost = 16894.4061
# Gen 500: Best Cost = 16637.6003
# Gen 600: Best Cost = 16443.1224
# Gen 700: Best Cost = 16297.5032
# Gen 800: Best Cost = 16179.0308
# Gen 900: Best Cost = 16039.2453
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  18717.20987451334
# GA Solution:    15897.72224470308
# IMPROVEMENT:    2819.487629810261 (15.06%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 2===")
case=Problem(1000, density=0.2, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 53802463.3292
# Gen 100: Best Cost = 35885931.3839
# Gen 200: Best Cost = 32879389.3133
# Gen 300: Best Cost = 31465127.2477
# Gen 400: Best Cost = 30358139.7348
# Gen 500: Best Cost = 29281545.6415
# Gen 600: Best Cost = 28754594.5251
# Gen 700: Best Cost = 28194660.1684
# Gen 800: Best Cost = 27654773.4137
# Gen 900: Best Cost = 27258199.6927
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  37545927.702134684
# GA Solution:    26874647.642273534
# IMPROVEMENT:    10671280.05986115 (28.42%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 3===")
case=Problem(1000, density=0.2, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 18598196530.4029
# Gen 100: Best Cost = 7995999212.1872
# Gen 200: Best Cost = 6663795185.6180
# Gen 300: Best Cost = 5997211828.8750
# Gen 400: Best Cost = 5525582111.6046
# Gen 500: Best Cost = 5172945123.4443
# Gen 600: Best Cost = 4923039792.2575
# Gen 700: Best Cost = 4711895768.6991
# Gen 800: Best Cost = 4553493796.3337
# Gen 900: Best Cost = 4415679438.4637
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  10600895130.62203
# GA Solution:    4322062922.532566
# IMPROVEMENT:    6278832208.089464 (59.23%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 1, beta 5===")
case=Problem(1000, density=0.2, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 1, beta 5===
# Pre-computing detailed path costs (Optimized)...
# Pre-computation complete.
# Starting Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 5118072043617239.0000
# Gen 100: Best Cost = 718685278252870.6250
# Gen 200: Best Cost = 451646029047353.2500
# Gen 300: Best Cost = 337805962485623.2500
# Gen 400: Best Cost = 279566499486597.2188
# Gen 500: Best Cost = 234948984194626.6875
# Gen 600: Best Cost = 203375094893466.8750
# Gen 700: Best Cost = 185327316311185.5312
# Gen 800: Best Cost = 170685380953481.8750
# Gen 900: Best Cost = 156392515172373.8125
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  1575163721306340.5
# GA Solution:    148146567008243.62
# IMPROVEMENT:    1427017154298097.0 (90.59%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 0.2, alpha 2, beta 1===")
case=Problem(1000, density=0.2, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 0.2, alpha 2, beta 1===
# Pre-computing detailed path costs (Optimized)...
# Pre-computation complete.
# Starting Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 446126.6389
# Gen 100: Best Cost = 398800.2678
# Gen 200: Best Cost = 391995.7636
# Gen 300: Best Cost = 390563.5883
# Gen 400: Best Cost = 390062.9297
# Gen 500: Best Cost = 390025.9449
# Gen 600: Best Cost = 390020.4995
# Gen 700: Best Cost = 390014.2312
# Gen 800: Best Cost = 390009.6014
# Gen 900: Best Cost = 390006.7260
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  390028.7212628889
# GA Solution:    390003.9423945345
# IMPROVEMENT:    24.778868354449514 (0.01%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 1===")
case=Problem(1000, density=1, alpha=1, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 1===
# Pre-computing detailed path costs (Optimized)...
# Pre-computation complete.
# Starting Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 219339.2313
# Gen 100: Best Cost = 196054.1777
# Gen 200: Best Cost = 193544.2027
# Gen 300: Best Cost = 193073.3063
# Gen 400: Best Cost = 192946.1664
# Gen 500: Best Cost = 192920.3770
# Gen 600: Best Cost = 192906.3574
# Gen 700: Best Cost = 192899.4621
# Gen 800: Best Cost = 192893.0607
# Gen 900: Best Cost = 192885.5462
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  192936.23377726728
# GA Solution:    192878.94316727808
# IMPROVEMENT:    57.290609989198856 (0.03%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 0.5===")
case=Problem(1000, density=1, alpha=1, beta=0.5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 0.5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 14187.6801
# Gen 100: Best Cost = 13214.6162
# Gen 200: Best Cost = 12937.7098
# Gen 300: Best Cost = 12758.6673
# Gen 400: Best Cost = 12591.2048
# Gen 500: Best Cost = 12461.9072
# Gen 600: Best Cost = 12347.0534
# Gen 700: Best Cost = 12265.3547
# Gen 800: Best Cost = 12184.3919
# Gen 900: Best Cost = 12103.0270
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  13456.958529427162
# GA Solution:    12031.821462820866
# IMPROVEMENT:    1425.1370666062958 (10.59%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 2===")
case=Problem(1000, density=1, alpha=1, beta=2)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 2===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 82931488.5016
# Gen 100: Best Cost = 58165102.9202
# Gen 200: Best Cost = 54252122.4111
# Gen 300: Best Cost = 52443060.8854
# Gen 400: Best Cost = 51034818.9076
# Gen 500: Best Cost = 49865389.7901
# Gen 600: Best Cost = 49187631.4714
# Gen 700: Best Cost = 48608116.4261
# Gen 800: Best Cost = 48148478.3697
# Gen 900: Best Cost = 47676089.5106
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  57580018.86872494
# GA Solution:    47372332.62396079
# IMPROVEMENT:    10207686.24476415 (17.73%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 3===")
case=Problem(1000, density=1, alpha=1, beta=3)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 3===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 40133403086.0281
# Gen 100: Best Cost = 19719238081.6173
# Gen 200: Best Cost = 17231230889.7332
# Gen 300: Best Cost = 15962982973.3838
# Gen 400: Best Cost = 15128834017.3873
# Gen 500: Best Cost = 14471957443.3546
# Gen 600: Best Cost = 14023723392.4287
# Gen 700: Best Cost = 13770275911.5713
# Gen 800: Best Cost = 13394075410.2148
# Gen 900: Best Cost = 13064158910.6471
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  20943050223.626434
# GA Solution:    12884117191.415758
# IMPROVEMENT:    8058933032.210676 (38.48%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 1, beta 5===")
case=Problem(1000, density=1, alpha=1, beta=5)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 1, beta 5===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 17390208983543978.0000
# Gen 100: Best Cost = 3558829905449485.0000
# Gen 200: Best Cost = 2503559727484019.0000
# Gen 300: Best Cost = 2018408041450927.0000
# Gen 400: Best Cost = 1788869393990661.2500
# Gen 500: Best Cost = 1579911634428577.2500
# Gen 600: Best Cost = 1427223890004287.7500
# Gen 700: Best Cost = 1327825822974563.2500
# Gen 800: Best Cost = 1254381963410554.5000
# Gen 900: Best Cost = 1177071033782211.5000
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  3798422113393744.0
# GA Solution:    1114911232894644.5
# IMPROVEMENT:    2683510880499099.5 (70.65%)
# ----------------------------------------

# %%
print("===Test Case: 1000 cities, density 1, alpha 2, beta 1===")
case=Problem(1000, density=1, alpha=2, beta=1)    
best_path = solution(case)
# Out:
# ===Test Case: 1000 cities, density 1, alpha 2, beta 1===
# Pre-computing path costs...
# Pre-computation complete.
# Running Genetic Algorithm (1000 generations)...
# Gen 0: Best Cost = 441312.5743
# Gen 100: Best Cost = 391249.8058
# Gen 200: Best Cost = 386354.9578
# Gen 300: Best Cost = 385222.4649
# Gen 400: Best Cost = 385110.3632
# Gen 500: Best Cost = 385094.6153
# Gen 600: Best Cost = 385084.0660
# Gen 700: Best Cost = 385077.8531
# Gen 800: Best Cost = 385071.0324
# Gen 900: Best Cost = 385062.9439
#
# Calculating Baseline...
# ----------------------------------------
# RESULTS:
# Baseline Cost:  385105.6414957661
# GA Solution:    385056.41916287417
# IMPROVEMENT:    49.22233289194992 (0.01%)
# ----------------------------------------
